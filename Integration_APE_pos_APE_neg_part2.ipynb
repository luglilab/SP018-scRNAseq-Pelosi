# %%
import scanpy as sc
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
from matplotlib import colors
import seaborn as sb
from gprofiler import GProfiler
import loompy as lp
import rpy2.rinterface_lib.callbacks
import logging
import scrublet as scr
from rpy2.robjects import pandas2ri
import anndata2ri

# %%
sc.logging.print_header()
# Out:
# scanpy==1.6.0 anndata==0.7.5 umap==0.4.6 numpy==1.19.4 scipy==1.4.1 pandas==1.1.4 scikit-learn==0.23.2 statsmodels==0.12.1 python-igraph==0.8.3 louvain==0.7.0 leidenalg==0.8.3

# %%
# Ignore R warning messages
#Note: this can be commented out to get more verbose R output
rpy2.rinterface_lib.callbacks.logger.setLevel(logging.ERROR)

# Automatically convert rpy2 outputs to pandas dataframes
pandas2ri.activate()
anndata2ri.activate()
# %load_ext rpy2.ipython

plt.rcParams['figure.figsize']=(8,8) #rescale figures
sc.settings.verbosity = 3
#sc.set_figure_params(dpi=200, dpi_save=300)
sc.logging.print_header()
# Out:
# scanpy==1.6.0 anndata==0.7.5 umap==0.4.6 numpy==1.19.4 scipy==1.4.1 pandas==1.1.4 scikit-learn==0.23.2 statsmodels==0.12.1 python-igraph==0.8.3 louvain==0.7.0 leidenalg==0.8.3

# %%
# %%R
# # Load libraries from correct lib Paths for my environment - ignore this!
# .libPaths("/home/spuccio/miniconda3/envs/scrnseq/lib/R/library")
#
# # Load all the R libraries we will be using in the notebook
# library(scran)
# library(RColorBrewer)
# library(slingshot)
# library(monocle)
# library(gam)
# library(clusterExperiment)
# library(ggplot2)
# library(plyr)
# library(MAST)
# library(clustree)
# library(SingleCellExperiment)
# library(CHETAH)
# library(SingleR)
# library(cowplot)
# library(Matrix)

# %% [markdown]
# ### Data Recall

# %%
adata = sc.read("/home/spuccio/homeserver2/SP018_Pelosi/Integration_APE_pos_APE_neg/Desc.h5ad")
adata2 = sc.read("/home/spuccio/homeserver2/SP018_Pelosi/Integration_APE_pos_APE_neg/No_Desc.h5ad")

# %%
adata.shape == adata2.shape
# Out:
# True

# %% [markdown]
# ### Clustree

# %%
data_clus = adata2.obs[['desc_0.4','desc_0.6','desc_0.7','desc_0.8']]

# %%
data_clus.columns
# Out:
# Index(['desc_0.4', 'desc_0.6', 'desc_0.7', 'desc_0.8'], dtype='object')

# %%
data_clus.columns = ['desc_r4_clusters', 'desc_r6_clusters', 'desc_r7_clusters', 'desc_r8_clusters']

# %%
data_clus.to_csv("/home/spuccio/homeserver2/SP018_Pelosi/Temp/temp.csv",index=True,header=True)
data_clus2 = pd.read_csv("/home/spuccio/homeserver2/SP018_Pelosi/Temp/temp.csv",index_col=0,header=0)

# %%
# these are the defaults we want to set:
default_units = 'in' # inch, to make it more easily comparable to matpplotlib
default_res = 100 # dpi, same as default in matplotlib
default_width = 10
default_height = 9
# try monkey-patching a function in rpy2, so we effectively get these
# default settings for the width, height, and units arguments of the %R magic command

old_setup_graphics = rpy2.ipython.rmagic.RMagics.setup_graphics

def new_setup_graphics(self, args):
    if getattr(args, 'units') is not None:
        if args.units != default_units: # a different units argument was passed, do not apply defaults
            return old_setup_graphics(self, args)
    args.units = default_units
    if getattr(args, 'res') is None:
        args.res = default_res
    if getattr(args, 'width') is None:
        args.width = default_width
    if getattr(args, 'height') is None:
        args.height = default_height        
    return old_setup_graphics(self, args)

rpy2.ipython.rmagic.RMagics.setup_graphics = new_setup_graphics

# %%
# %%R -i data_clus2
# library(clustree)
#
# clustree(data_clus2,prefix="desc_r",suffix = "_clusters")

# %% [markdown]
# ### Resolution 0.4

# %%
def run_vis(adata):
    if 'X_emb' in adata.obsm:
        sc.pp.neighbors(adata, use_rep='X_emb')
        sc.tl.umap(adata)
    else:
        sc.pp.pca(adata, svd_solver='arpack')
        sc.pp.neighbors(adata)
        sc.tl.umap(adata)

# %%
adata2.obsm['X_emb'] = adata2.obsm['X_Embeded_z'+str(0.4)]
run_vis(adata2)
# Out:
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:01)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:17)

# %%
adata2.obs['dataset'] = adata2.obs['dataset'].astype(str)

# %%
adata2
# Out:
# AnnData object with n_obs × n_vars = 6725 × 19286
#     obs: 'dataset', 'batch', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'pct_counts_mt', 'total_counts_rb', 'pct_counts_rb', 'n_counts', 'desc_0.4', 'desc_0.5', 'desc_0.6', 'desc_0.7', 'desc_0.8'
#     var: 'gene_ids', 'feature_types', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'mt', 'rb', 'gene_biotype'
#     uns: 'prob_matrix0.4', 'prob_matrix0.5', 'prob_matrix0.6', 'prob_matrix0.7', 'prob_matrix0.8', 'umap', 'neighbors', 'dataset_colors', 'desc_0.4_colors', 'rank_genes_groups', "dendrogram_['desc_0.4']", 'dendrogram_desc_0.4', 'desc_0.6_colors', "dendrogram_['desc_0.6']", 'dendrogram_desc_0.6', 'desc_0.8_colors', "dendrogram_['desc_0.8']", 'dendrogram_desc_0.8'
#     obsm: 'X_Embeded_z0.4', 'X_Embeded_z0.5', 'X_Embeded_z0.6', 'X_Embeded_z0.7', 'X_Embeded_z0.8', 'X_umap', 'X_umap0.4', 'X_umap0.5', 'X_umap0.6', 'X_umap0.7', 'X_umap0.8', 'X_emb', 'X_pca'
#     obsp: 'connectivities', 'distances'

# %%
sc.pl.umap(adata2, color='dataset'); plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(1,2, figsize=(33/2.54, 17/2.54))
ax1 = adata2.obs.groupby("desc_0.4")["dataset"].value_counts(normalize=False).unstack().plot.bar(stacked=True,legend=False,ax=ax1)
ax1.set_xlabel("Cluster")
ax1.set_ylabel("% Frequency")
ax1.grid(False)
ax1.legend(bbox_to_anchor=(1.1, 1.0))
ax2 = adata2.obs.groupby("desc_0.4")["dataset"].value_counts(normalize=True).unstack().plot.bar(stacked=True,legend=False,ax=ax2)
ax2.set_xlabel("Cluster")
ax2.set_ylabel("% Frequency")
ax2.grid(False)
ax2.legend(bbox_to_anchor=(1.1, 1.0))

# %%
rcParams['figure.figsize'] = 8, 8
sc.pl.umap(adata2, color='desc_0.4', add_outline=True,legend_loc='on data', 
           legend_fontsize=14, legend_fontoutline=2,frameon=False,
           title='desc_0.4', palette='Set1')

# %% [markdown]
# ### Compute Markers Gene Resolution 0.4

# %%
adata2.var.index = adata2.var.index.astype(str)
adata2.raw.var.index = adata2.raw.var.index.astype(str)
adata2.raw.index = adata2.var.index

# %%
sc.tl.rank_genes_groups(adata2, 'desc_0.4', method='wilcoxon')
pd.DataFrame(adata2.uns['rank_genes_groups']['names']).head(25)
# Out:
# ranking genes
#     finished: added to `.uns['rank_genes_groups']`
#     'names', sorted np.recarray to be indexed by group ids
#     'scores', sorted np.recarray to be indexed by group ids
#     'logfoldchanges', sorted np.recarray to be indexed by group ids
#     'pvals', sorted np.recarray to be indexed by group ids
#     'pvals_adj', sorted np.recarray to be indexed by group ids (0:00:09)
#           0         1         2         3        4         5         6  \
# 0       AVP      EREG      CD99      SNX3     MZB1    TYROBP     STMN1
# 1     CRHBP     GATA2     ITM2C     RGS10     CD99    FCER1G    TUBA1B
# 2      HOPX    FCER1A     NPDC1   C1orf54     DNTT      LST1      TYMS
# 3     MLLT3  SERPINB1    SPINK2  HLA-DPA1     NKG7    S100A6       DUT
# 4      BEX1     CYTL1   C1QTNF4      CD74   JCHAIN      FTH1     GAPDH
# 5       MDK      PKIG     ANXA1    CLEC9A      LTB   S100A11      TUBB
# 6    SPINK2      SOX4       VIM   HLA-DMA    ITM2C      CTSS     PCLAF
# 7       ID1   CTNNBL1     EGFL7     BATF3   SPINK2     IGSF6      LDHB
# 8     EGFL7      MPP1      FHL1      CPVL      ADA    S100A4     HMGB1
# 9       ID3     PDZD8      HOPX     HLA-B     HCST       FTL      NASP
# 10     KLF2   SLC40A1     MTURN  HLA-DPB1    SPNS3     CEBPD    RANBP1
# 11    SOCS2    CNRIP1       TKT      IRF8    IGLL1  SH3BGRL3      ENO1
# 12    NPDC1       PNN      PTMS      CD83    ARMH1     COTL1      PTMA
# 13     BST2      LDHB   TSC22D1     GSTP1  TSC22D1      CTSH    EEF1A1
# 14     TFPI    RNF130     ARMH1       ID2     ACY3    LGALS3      YBX1
# 15     FHL1    PRSS57    SMIM24     ACTG1   TMSB4X      MNDA       RAN
# 16    BAALC     HACD1    PRSS57   HLA-DRA    CD79A      OAZ1       DEK
# 17    RAB13      LYL1    MBOAT7   S100A10     LAT2    LAPTM5     HMGB2
# 18    RBPMS      ZEB2    PBXIP1   SLC25A6    BAALC      SRGN     HSPD1
# 19     BEX2  HSP90AB1       CD9      PLEK    STMN1       CFP    EEF1B2
# 20    MSRB3     EMID1   ANKRD28  HLA-DRB1   CORO1A      CD48    CHCHD2
# 21  ANKRD28     GATA1     NUCB2     COX7C    LAIR1       LYZ     HMGN2
# 22   PBXIP1      AMD1  SERPINB1     CPNE3    DUSP6      JAML   SLC25A5
# 23    NRIP1   PHACTR4    TSPAN2  HLA-DQB1     HOPX     TIMP1  HSP90AA1
# 24    SKAP1       HBD      CD34      CTSZ     TCF4    LGALS1     NUCB2
#
#            7         8
# 0       IL7R    SEC61B
# 1      KLRB1     PLAC8
# 2       BTG1    CCDC50
# 3    TNFAIP3      TCF4
# 4        LTB      IRF7
# 5        CD7      GZMB
# 6       IL32     SPCS1
# 7     CDC14A     IL3RA
# 8       CTSW  C12orf75
# 9      GATA3    LILRA4
# 10      CD69  PPP1R14B
# 11      TCF7      UGCG
# 12  TNFRSF18      MZB1
# 13   TSC22D3    SEC61G
# 14      EML4    JCHAIN
# 15    TMSB4X       SCT
# 16      ETS1     DERL3
# 17     HLA-C  SERPINF1
# 18     CALM1      IRF8
# 19   GADD45B   ALOX5AP
# 20     HLA-B      SPIB
# 21      JUNB    FCER1G
# 22      CD48      NPC2
# 23    STK17B     CXCR4
# 24      EIF1      SSR4

# %%
sc.tl.dendrogram(adata2, 'desc_0.4')
ax = sc.pl.dendrogram(adata2, 'desc_0.4')
# Out:
# WARNING: You’re trying to run this on 19286 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# computing PCA
#     with n_comps=50
#     finished (0:00:08)
# Storing dendrogram info using `.uns["dendrogram_['desc_0.4']"]`
# WARNING: dendrogram data not found (using key=dendrogram_desc_0.4). Running `sc.tl.dendrogram` with default parameters. For fine tuning it is recommended to run `sc.tl.dendrogram` independently.
#     using 'X_pca' with n_pcs = 50
# Storing dendrogram info using `.uns['dendrogram_desc_0.4']`

# %%
ax = sc.pl.correlation_matrix(adata2, 'desc_0.4', figsize=(5,3.5))

# %% [markdown]
# ### Export Resolution 0.4

# %%
result = adata2.uns['rank_genes_groups']

# %%
groups = result['names'].dtype.names
pd.DataFrame(
    {group + '_' + key[:3]: result[key][group]
    for group in groups for key in ['names', 'pvals','logfoldchanges']}).to_csv("/home/spuccio/homeserver2/SP018_Pelosi/Integration_APE_pos_APE_neg/Integrated_res04_DEGS.csv",header=True,index=False)

# %% [markdown]
# colors2 = plt.cm.Reds(np.linspace(0, 1, 128))
# colors3 = plt.cm.Greys_r(np.linspace(0.7,0.8,20))
# colorsComb = np.vstack([colors3, colors2])
# mymap = colors.LinearSegmentedColormap.from_list('my_colormap', colorsComb)
# sc.pl.umap(adata2, color=['CD226','CXCR4'],color_map=mymap,add_outline=True,legend_loc='on data',use_raw=True )

# %%
#rcParams['figure.figsize'] = 5,5
#sc.pl.violin(adata2, ['CD226','CXCR4','ADAM12','TEX13A'], groupby='desc_0.4')

# %%
rcParams['figure.figsize'] = 5,5
sc.pl.violin(adata2, ['CD226','CXCR4'], groupby='desc_0.6')
# Out:
# /home/spuccio/miniconda3/envs/integration/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/spuccio/miniconda3/envs/integration/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/spuccio/miniconda3/envs/integration/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/spuccio/miniconda3/envs/integration/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Analysis Resolution 0.6

# %%
adata2.obsm['X_emb'] = adata2.obsm['X_Embeded_z'+str(0.6)]
run_vis(adata2)
# Out:
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:01)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:18)

# %%
adata2.obs['dataset'] = adata2.obs['dataset'].astype(str)

# %%
sc.pl.umap(adata2, color='dataset'); plt.show()
# Out:
# ... storing 'dataset' as categorical

# %%
fig, (ax1,ax2) = plt.subplots(1,2, figsize=(33/2.54, 17/2.54))
ax1 = adata2.obs.groupby("desc_0.6")["dataset"].value_counts(normalize=False).unstack().plot.bar(stacked=True,legend=False,ax=ax1)
ax1.set_xlabel("Cluster")
ax1.set_ylabel("% Frequency")
ax1.grid(False)
ax1.legend(bbox_to_anchor=(1.1, 1.0))
ax2 = adata2.obs.groupby("desc_0.6")["dataset"].value_counts(normalize=True).unstack().plot.bar(stacked=True,legend=False,ax=ax2)
ax2.set_xlabel("Cluster")
ax2.set_ylabel("% Frequency")
ax2.grid(False)
ax2.legend(bbox_to_anchor=(1.1, 1.0))

# %%
rcParams['figure.figsize'] = 8, 8
sc.pl.umap(adata2, color='desc_0.6', add_outline=True,legend_loc='on data', 
           legend_fontsize=14, legend_fontoutline=2,frameon=False,
           title='desc_0.6', palette='Set1')

# %% [markdown]
# ### Compute Markers Gene Resolution 0.6

# %%
sc.tl.rank_genes_groups(adata2, 'desc_0.6', method='wilcoxon')
pd.DataFrame(adata2.uns['rank_genes_groups']['names']).head(25)
# Out:
# ranking genes
#     finished: added to `.uns['rank_genes_groups']`
#     'names', sorted np.recarray to be indexed by group ids
#     'scores', sorted np.recarray to be indexed by group ids
#     'logfoldchanges', sorted np.recarray to be indexed by group ids
#     'pvals', sorted np.recarray to be indexed by group ids
#     'pvals_adj', sorted np.recarray to be indexed by group ids (0:00:08)
#           0         1         2         3        4         5         6  \
# 0       AVP      EREG      CD99      SNX3     MZB1    TYROBP     STMN1
# 1     CRHBP     GATA2     ITM2C     RGS10     DNTT    FCER1G    TUBA1B
# 2      HOPX    FCER1A     NPDC1  HLA-DPA1     CD99      LST1       DUT
# 3     MLLT3  SERPINB1    SPINK2   C1orf54      LTB    S100A6      TYMS
# 4      BEX1     CYTL1   C1QTNF4      CD74   JCHAIN      FTH1     GAPDH
# 5       MDK      PKIG      FHL1     BATF3     NKG7      CTSS     PCLAF
# 6       ID1      SOX4     ANXA1   HLA-DMA    ITM2C   S100A11      LDHB
# 7    SPINK2   CTNNBL1     EGFL7  HLA-DPB1   SPINK2     IGSF6     HMGB1
# 8     EGFL7      MPP1      HOPX     HLA-B      ADA       FTL      TUBB
# 9      KLF2   SLC40A1       VIM      CPVL    SPNS3    S100A4      NASP
# 10      ID3     PDZD8   TSC22D1     GSTP1     HCST  SH3BGRL3      PTMA
# 11    SOCS2       PNN    PRSS57    CLEC9A    ARMH1     CEBPD    RANBP1
# 12    NPDC1    CNRIP1       TKT      IRF8     HOPX     COTL1      ENO1
# 13     BST2      LDHB     ARMH1   S100A10     ACY3      CTSH      YBX1
# 14     TFPI    RNF130    SMIM24      CD83  TSC22D1      OAZ1       RAN
# 15    RAB13    PRSS57     MTURN     ACTG1    IGLL1      SRGN     HSPD1
# 16    BAALC     HACD1      PTMS       ID2    CD79A    LGALS3       DEK
# 17     FHL1      LYL1    MBOAT7   HLA-DRA    BAALC    LAPTM5    EEF1A1
# 18    RBPMS      ZEB2    PBXIP1  HLA-DQB1    LAIR1      MNDA    CHCHD2
# 19     BEX2     EMID1     NUCB2   SLC25A6     LAT2      CYBA      PPIA
# 20  ANKRD28      AMD1  SERPINB1      PLEK    DUSP6       CFP     HMGB2
# 21   PBXIP1   PHACTR4      TPT1  HLA-DRB1    PRSS2    LGALS1   SLC25A5
# 22    NRIP1     GATA1      CD34     CPNE3  C1QTNF4      CD48  HSP90AA1
# 23    MSRB3  HSP90AB1   ANKRD28     COX7C    CD79B     ARPC3     NUCB2
# 24    SKAP1       HBD     HINT1    TMSB4X   VPREB1      SPI1     HMGN2
#
#            7         8
# 0       IL7R    SEC61B
# 1      KLRB1      TCF4
# 2       BTG1     PLAC8
# 3    TNFAIP3    CCDC50
# 4        LTB      IRF7
# 5        CD7     IL3RA
# 6       IL32     SPCS1
# 7       CTSW    JCHAIN
# 8     CDC14A      GZMB
# 9      GATA3      MZB1
# 10      CD69  PPP1R14B
# 11      TCF7    LILRA4
# 12  TNFRSF18  C12orf75
# 13   TSC22D3       SCT
# 14      EML4      UGCG
# 15    TMSB4X      IRF8
# 16      ETS1      SPIB
# 17     CALM1     DERL3
# 18   GADD45B    SEC61G
# 19      JUNB      SSR4
# 20     HLA-C     CXCR4
# 21      CD48  SERPINF1
# 22     HLA-B    FCER1G
# 23      EIF1      PLD4
# 24       EVL   ALOX5AP

# %%
sc.tl.dendrogram(adata2, 'desc_0.6')
ax = sc.pl.dendrogram(adata2, 'desc_0.6')
# Out:
#     using 'X_pca' with n_pcs = 50
# Storing dendrogram info using `.uns["dendrogram_['desc_0.6']"]`
# WARNING: dendrogram data not found (using key=dendrogram_desc_0.6). Running `sc.tl.dendrogram` with default parameters. For fine tuning it is recommended to run `sc.tl.dendrogram` independently.
#     using 'X_pca' with n_pcs = 50
# Storing dendrogram info using `.uns['dendrogram_desc_0.6']`

# %%
ax = sc.pl.correlation_matrix(adata2, 'desc_0.6', figsize=(5,3.5))

# %% [markdown]
# ### Export Resolution 0.6

# %%
result = adata2.uns['rank_genes_groups']

# %%
groups = result['names'].dtype.names
pd.DataFrame(
    {group + '_' + key[:3]: result[key][group]
    for group in groups for key in ['names', 'pvals','logfoldchanges']}).to_csv("/home/spuccio/homeserver2/SP018_Pelosi/Integration_APE_pos_APE_neg/Integrated_res06_DEGS.csv",header=True,index=False)

# %% [markdown]
# ### Resolution 0.8

# %%
adata2.obsm['X_emb'] = adata2.obsm['X_Embeded_z'+str(0.8)]
run_vis(adata2)
# Out:
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:01)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:17)

# %%
adata2.obs['dataset'] = adata2.obs['dataset'].astype(str)

# %%
sc.pl.umap(adata2, color='dataset'); plt.show()
# Out:
# ... storing 'dataset' as categorical

# %%
fig, (ax1,ax2) = plt.subplots(1,2, figsize=(33/2.54, 17/2.54))
ax1 = adata2.obs.groupby("desc_0.8")["dataset"].value_counts(normalize=False).unstack().plot.bar(stacked=True,legend=False,ax=ax1)
ax1.set_xlabel("Cluster")
ax1.set_ylabel("% Frequency")
ax1.grid(False)
ax1.legend(bbox_to_anchor=(1.1, 1.0))
ax2 = adata2.obs.groupby("desc_0.8")["dataset"].value_counts(normalize=True).unstack().plot.bar(stacked=True,legend=False,ax=ax2)
ax2.set_xlabel("Cluster")
ax2.set_ylabel("% Frequency")
ax2.grid(False)
ax2.legend(bbox_to_anchor=(1.1, 1.0))

# %%
rcParams['figure.figsize'] = 8, 8
sc.pl.umap(adata2, color='desc_0.8', add_outline=True,legend_loc='on data', 
           legend_fontsize=14, legend_fontoutline=2,frameon=False,
           title='desc_0.8', palette='Set1')

# %% [markdown]
# ### Compute Markers Gene Resolution 0.8

# %%
sc.tl.rank_genes_groups(adata2, 'desc_0.8', method='wilcoxon')
pd.DataFrame(adata2.uns['rank_genes_groups']['names']).head(25)
# Out:
# ranking genes
#     finished: added to `.uns['rank_genes_groups']`
#     'names', sorted np.recarray to be indexed by group ids
#     'scores', sorted np.recarray to be indexed by group ids
#     'logfoldchanges', sorted np.recarray to be indexed by group ids
#     'pvals', sorted np.recarray to be indexed by group ids
#     'pvals_adj', sorted np.recarray to be indexed by group ids (0:00:09)
#           0         1        2        3         4         5        6  \
# 0       AVP      EREG      AVP     CD99      SNX3  SERPINB1     DNTT
# 1    SPINK2    FCER1A    MLLT3    ITM2C     RGS10      CD99     MZB1
# 2     EGFL7     GATA2    CRHBP    NPDC1   C1orf54     NUCB2     CD99
# 3      HOPX  SERPINB1     KLF2   SPINK2      CD74     HINT1      LTB
# 4      CD69     CYTL1      MDK     HOPX  HLA-DPA1     RACK1   JCHAIN
# 5     CRHBP      PKIG     HOPX  C1QTNF4      CPVL    SPINK2     NKG7
# 6   C1QTNF4   CTNNBL1     BEX1      VIM  HLA-DPB1   ANKRD28    ITM2C
# 7      BEX1      SOX4      ID1     PTMS     HLA-B    EEF1A1      ADA
# 8      EGR1      MPP1      ID3    ANXA1      IRF8    PRSS57    SPNS3
# 9       MDK   SLC40A1    SOCS2     FHL1    CLEC9A   C1QTNF4     HCST
# 10     NPR3    CNRIP1     BST2    EGFL7   S100A10     EGFL7  TSC22D1
# 11    MLLT3     PDZD8    EGFL7    MTURN     GSTP1      CDK6     ACY3
# 12    CXCL8       PNN   SPINK2   SMIM24     BATF3     ARMH1    IGLL1
# 13    NPDC1    RNF130     TFPI  TSC22D1   HLA-DMA      TPT1    CD79A
# 14     FHL1      LDHB   TCEAL2   TSPAN2       ID2      BTF3   TMSB4X
# 15   SMIM24    PRSS57    BAALC   MBOAT7  HLA-DQB1     GAPDH   SPINK2
# 16    BAALC      ZEB2      CLU    ARMH1   HLA-DRA      NPM1    ARMH1
# 17    NUCB2     HACD1   PBXIP1      TKT     ACTG1       TKT   LGALS1
# 18     BTG2     GATA1    NPDC1   PBXIP1  HLA-DRB1      LDHB     LAT2
# 19      ID1      AMD1    RAB13      AVP      CD83     NPDC1   CORO1A
# 20  ANKRD28     EMID1     FHL1      CD9   SLC25A6     ANXA1    LAIR1
# 21   ATP2C1  HSP90AB1    SKAP1     CD34      PLEK    SMIM24    DUSP6
# 22   ATP8B4       HBD    RBPMS    CRIP2    TMSB4X     PNISR    STMN1
# 23    RAB13      LYL1      IDS    HMGN3      CST3   TSC22D1    BAALC
# 24    SYPL1    STXBP6  C3orf80     CD52     BASP1      EEF2   VPREB1
#
#            7         8         9        10
# 0     TYROBP     STMN1      IL7R    SEC61B
# 1     FCER1G    TUBA1B     KLRB1      TCF4
# 2       LST1      TYMS      BTG1     PLAC8
# 3    S100A11       DUT   TNFAIP3    CCDC50
# 4     S100A6     PCLAF       LTB      IRF7
# 5       CTSS     HMGB1       CD7     IL3RA
# 6       FTH1     GAPDH      IL32     SPCS1
# 7      IGSF6      TUBB      CTSW    JCHAIN
# 8        FTL    RANBP1    CDC14A      GZMB
# 9   SH3BGRL3      NASP     GATA3  C12orf75
# 10    S100A4      LDHB      CD69      MZB1
# 11     CEBPD      PTMA      TCF7  PPP1R14B
# 12     COTL1       RAN  TNFRSF18    LILRA4
# 13      OAZ1     HMGB2   TSC22D3      UGCG
# 14      CTSH      ENO1      EML4       SCT
# 15    LGALS3      YBX1    TMSB4X      IRF8
# 16      MNDA       DEK     HLA-C      SPIB
# 17      SRGN  HSP90AA1      ETS1     DERL3
# 18    LAPTM5    CHCHD2     CALM1    SEC61G
# 19      CD48     HMGN2   GADD45B  SERPINF1
# 20      CYBA     HSPD1      JUNB      SSR4
# 21    LGALS1      PPIA     HLA-B     CXCR4
# 22      JAML   SLC25A5      CD48    FCER1G
# 23       CFP      TPI1       EVL      NPC2
# 24       LYZ    SNRPD1      EIF1   ALOX5AP

# %%
sc.tl.dendrogram(adata2, 'desc_0.8')
# Out:
#     using 'X_pca' with n_pcs = 50
# Storing dendrogram info using `.uns["dendrogram_['desc_0.8']"]`

# %%
ax = sc.pl.dendrogram(adata2, 'desc_0.8')
# Out:
# WARNING: dendrogram data not found (using key=dendrogram_desc_0.8). Running `sc.tl.dendrogram` with default parameters. For fine tuning it is recommended to run `sc.tl.dendrogram` independently.
#     using 'X_pca' with n_pcs = 50
# Storing dendrogram info using `.uns['dendrogram_desc_0.8']`

# %%
ax = sc.pl.correlation_matrix(adata2, 'desc_0.8', figsize=(5,3.5))

# %% [markdown]
# ### Export Resolution 0.8

# %%
result = adata2.uns['rank_genes_groups']

# %%
groups = result['names'].dtype.names
pd.DataFrame(
    {group + '_' + key[:3]: result[key][group]
    for group in groups for key in ['names', 'pvals','logfoldchanges']}).to_csv("/home/spuccio/homeserver2/SP018_Pelosi/Integration_APE_pos_APE_neg/Integrated_res08_DEGS.csv",header=True,index=False)

# %%
adata2.write("/mnt/spuccio_hpcserver2/SP018_Pelosi/Integration_APE_pos_APE_neg/Integrated_NEG_POS.h5ad")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 6725 × 19286
#     obs: 'dataset', 'batch', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'pct_counts_mt', 'total_counts_rb', 'pct_counts_rb'
#     var: 'gene_ids', 'feature_types', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'mt', 'rb', 'gene_biotype'
